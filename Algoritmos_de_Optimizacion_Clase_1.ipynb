# %% [markdown]
# <a href="https://colab.research.google.com/github/Mhernandezg/AlgoritmosOptimizacionVIU/blob/main/Algoritmos_de_Optimizacion_Clase_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a=[1,2,6,7,12,13,15]
b=[2,3,4,7,13]

print(a)
# Out:
# [1, 2, 6, 7, 12, 13, 15]

# %%
c=[]
d=[]
e=[]
for x in a:
 for y in b:
  if(x==y):
    c.append(x)

d=[x for x in a if x in b]

print(c)
print(d)
# Out:
# [2, 7, 13]
# [2, 7, 13]
